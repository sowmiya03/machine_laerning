# %%
import pandas as pd
import numpy as np

# %%
temp=pd.read_csv('Fish.csv')

# %%
data=temp.sample(frac=1)

# %%
df=data.sample(n=3)

# %%
y=data['Weight']

# %%
data=data.drop(['Species'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=0)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=reg.predict(x_test)

# %%
plt.plot(data,y,'o')
plt.title('FishWeightPrediction')
plt.xlabel('features')
plt.ylabel('weight')
plt.show()

# %%
import seaborn as seabornInstance
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['Weight'])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 25    725.0      725.0
# 131   300.0      300.0
# 153     9.8        9.8
# 140   950.0      950.0
# 12    500.0      500.0
# 142  1600.0     1600.0
# 158    19.9       19.9
# 154    12.2       12.2
# 151    10.0       10.0
# 10    475.0      475.0
# 15    600.0      600.0
# 147     7.0        7.0
# 85    130.0      130.0
# 94    150.0      150.0
# 120   900.0      900.0
# 13    340.0      340.0
# 141  1250.0     1250.0
# 32    925.0      925.0
# 83    115.0      115.0
# 102   300.0      300.0
# 128   200.0      200.0
# 146     7.5        7.5
# 45    160.0      160.0
# 49    161.0      161.0
# 5     450.0      450.0
# 23    680.0      680.0
# 118   820.0      820.0
# 60   1000.0     1000.0
# 53    272.0      272.0
# 90    110.0      110.0
# 69    200.0      200.0
# 0     242.0      242.0
